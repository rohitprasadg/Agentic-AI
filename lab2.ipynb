# %%
import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
from openai import OpenAI
MODEL = "llama3.2"
openai = OpenAI(base_url="http://localhost:11434/v1", api_key="ollama")
response = openai.chat.completions.create(
 model=MODEL,
 messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# What is the nature of personal identity and continuity in individuals like Henry Pretender, who has no memory before age 16, but undergoes a gradual shift through years of consistent experiences and self-narrative towards taking on an entirely new persona by age 35?

# %%
answers = []
messages = [{"role": "user", "content": question}]

# %%
model_name = MODEL

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
answers.append(answer)
# Out:
# The concept you're referring to is often called "continuous creation" or "continuous becoming," where an individual's sense of identity is formed through a process of gradual construction, revision, and reorganization over time. This perspective challenges traditional notions of personal identity as fixed, essential, and timeless.
#
# Henry Pretender's case raises interesting questions about the nature of self and continuity. Without any memories before age 16, it's likely that his sense of identity was initially rooted in external sources such as family, culture, and social context rather than internal experiences or memories.
#
# As Henry navigates various experiences and creates a narrative about himself, he gradually transforms into a new persona by age 35. This transformation is likely driven by a complex interplay between internal factors (e.g., cognitive biases, emotional needs) and external influences (e.g., social pressures, cultural expectations).
#
# From a theoretical perspective, this phenomenon can be understood through various frameworks:
#
# 1. **Social Constructionism**: Henry's self-identity is constructed through social interactions, relationships, and cultural norms. As he navigates these experiences, his identity is shaped by the collective meanings attributed to him.
# 2. **Narrative Identity Theory (NIT)**: According to NIT, individuals construct their sense of self through storytelling and shared values. Henry's narrative about himself is constantly evolving as he accumulates experiences and adjusts his personal values and attitudes.
# 3. **Developmental Psychodynamics**: This perspective emphasizes the role of psychological development and growth in shaping identity. As Henry matures and experiences various challenges and successes, his internalized sense of self evolves and adapts to these changes.
# 4. **Embodied Cognition Theory**: Henry's body and senses are deeply embedded in his experiences and interactions with the world. As he navigates new social roles, relationships, and environments, his physical self incorporates aspects of the newly constructed identity.
#
# Key questions arise from this phenomenon:
#
# * Is Henry still the same person before and after his transformation?
# * Where lies the core, essential Henry Pretender – a combination of past experiences, memories, values, or something else?
# * Can self-identity be considered as an ongoing process of discovery, revision, and construction?
#
# Theories like these acknowledge that identity is not fixed but dynamic and multifaceted. Identity emerges from interactions between internal processes (e.g., thoughts, emotions) and external contexts (e.g., social norms, cultural expectations).
#
# Ultimately, the nature of personal identity in individuals like Henry Pretender underscores the complex interplay between self-formation, experiences, and context-shaping factors.
